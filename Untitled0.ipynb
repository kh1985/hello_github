# %% [markdown]
# <a href="https://colab.research.google.com/github/kh1985/hello_github/blob/master/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install --upgrade -q gspread
#!pip install -U tensorflow-gpu==2.0.0 grpcio

import requests
from bs4 import BeautifulSoup
import re
import json
from google.colab import auth
import gspread
from oauth2client.client import GoogleCredentials
import types
import time
from google.colab import drive
import csv

#スプレッドシート認証処理
auth.authenticate_user()
gc = gspread.authorize(GoogleCredentials.get_application_default())

#ティッカー一覧を取得
ss_url = "初心者のための投資講座"
workbook = gc.open(ss_url)
worksheet = workbook.worksheet("ticker_list")
#cell_list = worksheet.range("A3:A3865")
cell_list = []
for cell in worksheet.range("A3:A90"):
  cell_list.append(cell.value)

class Settlement:
  BASE_FINANCIALS_URL='https://finance.yahoo.com/quote/{0}/financials?p={0}'
  BASE_CASHFLOW_URL='https://finance.yahoo.com/quote/{0}/cash-flow?p={0}'
  outPutDict = {}
  errCnt = 0
  waitCounter = 0
  WAIT_COUNT = 40

  def checkKey(target,key,selt):
    if key in target.keys():
      return true
    else:
      return false

  def getJScript(self,url):
    r = requests.get(url)
    
    html = r.text
    soup = BeautifulSoup(html,'html.parser')
    soup_script = soup.find("script",text=re.compile("root.App.main")).text
    return json.loads(re.search("root.App.main\s+=\s+(\{.*\})",soup_script)[1])
  
  def getData(self,i):
    try:
      fUrl = self.BASE_FINANCIALS_URL.format(cell_list[i])
      fJScript = self.getJScript(fUrl)
      fQSS = fJScript['context']['dispatcher']['stores']['QuoteSummaryStore']

      if fQSS['cashflowStatementHistory'] is None or len(fQSS['cashflowStatementHistory']) == 0:
        print("cashflowStatementHistory:None")
        return None
      else:
        fCFS = fQSS['cashflowStatementHistory']['cashflowStatements']
      fISH = fQSS['incomeStatementHistory']['incomeStatementHistory']

      #if fJScript['context']['dispatcher']['stores']['QuoteTimeSeriesStore']['timeSeries'] is None:
      #  print("timeSeries:None")
      #  return None
      #else:
      #  fADAS = fJScript['context']['dispatcher']['stores']['QuoteTimeSeriesStore']['timeSeries']['annualDilutedAverageShares']
      fADAS = fJScript['context']['dispatcher']['stores']['QuoteTimeSeriesStore']['timeSeries']['annualDilutedAverageShares']

      cUrl = self.BASE_CASHFLOW_URL.format(cell_list[i])
      cJScript = self.getJScript(cUrl)
      cQSS = cJScript['context']['dispatcher']['stores']['QuoteSummaryStore']

      cCFS = cQSS['cashflowStatementHistory']['cashflowStatements']
      
      #max3年のデータがほしいけど、0~2も存在する。
      roopCnt = len(fADAS) -1
      if roopCnt < 0:
        return None
      fadasiBaseCnt = roopCnt - 1

      #if cell_list[i] == 'ACET'
      #print("fCFS"+str(len(fCFS)))
      #print("fISH"+str(len(fISH)))
      #print("fADAS"+str(len(fADAS)))
      #print("cCFS"+str(len(cCFS)))
      
      #print("roopCnt:" + str(roopCnt))
      print("end:" + fUrl)

      for j in range(roopCnt):
         fadasi = fadasiBaseCnt-j
         dataDict = {}
         dataDict['endDate'] = fCFS[j]['endDate']['fmt'] if 'endDate' in fCFS[j].keys() else ''
         dataDict['netIncome'] = fCFS[j]['netIncome']['longFmt'] if 'netIncome' in fCFS[j].keys() else ''
         dataDict['totalRevenue'] = fISH[j]['totalRevenue']['longFmt'] if 'totalRevenue' in fISH[j].keys() else ''
         dataDict['reportedValue'] = fADAS[fadasi]['reportedValue']['raw'] if 'reportedValue' in fADAS[fadasi].keys() else ''
         dataDict['totalCashFromOperatingActivities'] = cCFS[j]['totalCashFromOperatingActivities']['longFmt'] if 'totalCashFromOperatingActivities' in fCFS[j].keys() else ''
         dataDict['dividendsPaid'] = cCFS[j]['dividendsPaid']['longFmt'] if 'dividendsPaid' in cCFS[j].keys() else ''

         # カンマ除去
         dataDict['netIncome'] = dataDict['netIncome'].replace(',', '')
         dataDict['totalRevenue'] = dataDict['totalRevenue'].replace(',', '')
         dataDict['totalCashFromOperatingActivities'] = dataDict['totalCashFromOperatingActivities'].replace(',', '')
         dataDict['dividendsPaid'] = dataDict['dividendsPaid'].replace('-', '') #配当は-は除去する
         dataDict['dividendsPaid'] = dataDict['dividendsPaid'].replace(',', '')

         key = cell_list[i] + '_' + dataDict['endDate']
         self.outPutDict[key] = dataDict
    except:
        if self.errCnt < 5:
          print("こけた！")
          self.errCnt = self.errCnt + 1
          self.getData(i)

  def getAllData(self):
    for i in range(len(cell_list)):
      self.errCnt = 0
      self.getData(i)
      self.waitCounter = self.waitCounter +1
      if self.waitCounter % self.WAIT_COUNT == 0:
        print("休憩")
        time.sleep(30)

S = Settlement()
allData = {}
S.getAllData()
allData = S.outPutDict

#drive.mount('/content/drive')
with open('/content/drive/My Drive/settlement.csv', 'a') as f:
  w = csv.writer(f)
  ky = 1
  worksheet_output_list = workbook.worksheet("output_list")
  for symbl,d in allData.items():
    kx = 1
    row = []
    for k,v in d.items():
      if kx == 1:
        row.append(symbl)
      else:
        row.append(v)
      kx += 1
    w.writerow(row)
    ky += 1
# Out:
# こけた！
# こけた！
# こけた！
# こけた！
# こけた！
# こけた！
# こけた！
# こけた！
# こけた！
# こけた！
# こけた！
# こけた！
# こけた！
# こけた！
# こけた！

# %%
# Out:
# 7618000000
# -1587000000

# %%
#本線
# !pip install --upgrade -q gspread
#!pip install -U tensorflow-gpu==2.0.0 grpcio

import requests
from bs4 import BeautifulSoup
import re
import json
from google.colab import auth
import gspread
from oauth2client.client import GoogleCredentials
import types
import time
from google.colab import drive
import csv

#スプレッドシート認証処理
auth.authenticate_user()
gc = gspread.authorize(GoogleCredentials.get_application_default())

#ティッカー一覧を取得
ss_url = "初心者のための投資講座"
workbook = gc.open(ss_url)
worksheet = workbook.worksheet("ticker_list")
#cell_list = worksheet.range("A3:A3865")
drive.mount('/content/drive')
cell_list = []
#for cell in worksheet.range("A3:A200"):
#for cell in worksheet.range("A1001:A1200"):
#for cell in worksheet.range("A2001:A2200"):
for cell in worksheet.range("A3001:A3200"):
  cell_list.append(cell.value)

class Settlement:
  BASE_FINANCIALS_URL='https://finance.yahoo.com/quote/{0}/financials?p={0}'
  BASE_CASHFLOW_URL='https://finance.yahoo.com/quote/{0}/cash-flow?p={0}'
  outPutDict = {}
  errCnt = 0
  waitCounter = 0
  WAIT_COUNT = 40

  def checkKey(target,key,selt):
    if key in target.keys():
      return true
    else:
      return false

  def getJScript(self,url):
    r = requests.get(url)
    
    html = r.text
    soup = BeautifulSoup(html,'html.parser')
    soup_script = soup.find("script",text=re.compile("root.App.main")).text
    return json.loads(re.search("root.App.main\s+=\s+(\{.*\})",soup_script)[1])
  
  def getData(self,i):
    try:
      fUrl = self.BASE_FINANCIALS_URL.format(cell_list[i])
      fJScript = self.getJScript(fUrl)
      fQSS = fJScript['context']['dispatcher']['stores']['QuoteSummaryStore']

      if fQSS['cashflowStatementHistory'] is None or len(fQSS['cashflowStatementHistory']) == 0:
        print("cashflowStatementHistory:None")
        return None
      else:
        fCFS = fQSS['cashflowStatementHistory']['cashflowStatements']
      fISH = fQSS['incomeStatementHistory']['incomeStatementHistory']

      #if fJScript['context']['dispatcher']['stores']['QuoteTimeSeriesStore']['timeSeries'] is None:
      #  print("timeSeries:None")
      #  return None
      #else:
      #  fADAS = fJScript['context']['dispatcher']['stores']['QuoteTimeSeriesStore']['timeSeries']['annualDilutedAverageShares']
      fADAS = fJScript['context']['dispatcher']['stores']['QuoteTimeSeriesStore']['timeSeries']['annualDilutedAverageShares']

      cUrl = self.BASE_CASHFLOW_URL.format(cell_list[i])
      cJScript = self.getJScript(cUrl)
      cQSS = cJScript['context']['dispatcher']['stores']['QuoteSummaryStore']

      cCFS = cQSS['cashflowStatementHistory']['cashflowStatements']
      
      #max3年のデータがほしいけど、0~2も存在する。
      roopCnt = len(fADAS) -1
      if roopCnt < 0:
        return None
      fadasiBaseCnt = roopCnt - 1

      #if cell_list[i] == 'ACET'
      #print("fCFS"+str(len(fCFS)))
      #print("fISH"+str(len(fISH)))
      #print("fADAS"+str(len(fADAS)))
      #print("cCFS"+str(len(cCFS)))
      
      #print("roopCnt:" + str(roopCnt))
      print("end:" + fUrl)

      for j in range(roopCnt):
         fadasi = fadasiBaseCnt-j
         dataDict = {}
         dataDict['endDate'] = fCFS[j]['endDate']['fmt'] if 'endDate' in fCFS[j].keys() else ''
         dataDict['netIncome'] = fCFS[j]['netIncome']['longFmt'] if 'netIncome' in fCFS[j].keys() else ''
         dataDict['totalRevenue'] = fISH[j]['totalRevenue']['longFmt'] if 'totalRevenue' in fISH[j].keys() else ''
         dataDict['reportedValue'] = fADAS[fadasi]['reportedValue']['raw'] if 'reportedValue' in fADAS[fadasi].keys() else ''
         dataDict['totalCashFromOperatingActivities'] = cCFS[j]['totalCashFromOperatingActivities']['longFmt'] if 'totalCashFromOperatingActivities' in fCFS[j].keys() else ''
         dataDict['dividendsPaid'] = cCFS[j]['dividendsPaid']['longFmt'] if 'dividendsPaid' in cCFS[j].keys() else ''

         # カンマ除去
         dataDict['netIncome'] = dataDict['netIncome'].replace(',', '')
         dataDict['totalRevenue'] = dataDict['totalRevenue'].replace(',', '')
         dataDict['totalCashFromOperatingActivities'] = dataDict['totalCashFromOperatingActivities'].replace(',', '')
         dataDict['dividendsPaid'] = dataDict['dividendsPaid'].replace('-', '') #配当は-は除去する
         dataDict['dividendsPaid'] = dataDict['dividendsPaid'].replace(',', '')

         #追加----
         dataDict['dps'] = dataDict['dividendsPaid'] / dataDict['reportedValue']
         dataDict['eps'] = dataDict['netIncome'] / dataDict['reportedValue']
         dataDict['cfps'] = dataDict['totalCashFromOperatingActivities'] / dataDict['reportedValue']
         dataDict['sps'] = dataDict['totalRevenue'] / dataDict['reportedValue']
         if dataDict['sps'] = 0:
           dataDict['ocf'] = 0
         else:
           dataDict['ocf'] = dataDict['cfps'] / dataDict['sps']

         #営業キャッシュ・フローが15%より大きいか
         if dataDict['ocf'] > 0.15:
           dataDict['ocfFlg'] = "true"
         else:
           dataDict['ocfFlg'] = "false"

         #営業キャッシュ・フローがEPSより大きいか
         if dataDict['ocf'] > dataDict['eps']:
           dataDict['ocfMoreThanEpsFlg'] = "true"
         else:
           dataDict['ocfMoreThanEpsFlg'] = "false"

         #年々営業キャッシュ・フローが増えているか
         if j = 0:
           dataDict['ybyyUpFlg'] = "unKnown"
         else if j = 1:
           if dataDict[0]['ocf'] > dataDict[1]['ocf']:
             dataDict[0]['ybyyUpFlg'] = "true"
           else:
             dataDict[0]['ybyyUpFlg'] = "false"
         else if j = 2:
           if dataDict[0]['ocf'] > dataDict[1]['ocf'] AND dataDict[1]['ocf'] > dataDict[2]['ocf']:
             dataDict[0]['ybyyUpFlg'] = "true"
           else:
             dataDict[0]['ybyyUpFlg'] = "false"

         #追加ここまで----

         key = cell_list[i] + '_' + dataDict['endDate']
         self.outPutDict[key] = dataDict
    except:
        if self.errCnt < 5:
          print("こけた！")
          self.errCnt = self.errCnt + 1
          self.getData(i)

  def getAllData(self):
    for i in range(len(cell_list)):
      self.errCnt = 0
      self.getData(i)
      time.sleep(6)

S = Settlement()
allData = {}
S.getAllData()
allData = S.outPutDict

with open('/content/drive/My Drive/settlement.csv', 'w') as f:
#with open('/content/drive/My Drive/settlement5.csv', 'w') as f:
#with open('/content/drive/My Drive/settlement10.csv', 'w') as f:
#with open('/content/drive/My Drive/settlement15.csv', 'w') as f:
  w = csv.writer(f)
  ky = 1
  worksheet_output_list = workbook.worksheet("output_list")
  for symbl,d in allData.items():
    kx = 1
    row = []
    for k,v in d.items():
      if kx == 1:
        row.append(symbl)
      else:
        row.append(v)
      kx += 1
    w.writerow(row)
    ky += 1
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# end:https://finance.yahoo.com/quote/TLRY/financials?p=TLRY
# end:https://finance.yahoo.com/quote/TLYS/financials?p=TLYS
# end:https://finance.yahoo.com/quote/TMDX/financials?p=TMDX
# end:https://finance.yahoo.com/quote/TMHC/financials?p=TMHC
# end:https://finance.yahoo.com/quote/TMO/financials?p=TMO
# end:https://finance.yahoo.com/quote/TMP/financials?p=TMP
# end:https://finance.yahoo.com/quote/TMST/financials?p=TMST
# end:https://finance.yahoo.com/quote/TMUS/financials?p=TMUS
# end:https://finance.yahoo.com/quote/TMX/financials?p=TMX
# end:https://finance.yahoo.com/quote/TNAV/financials?p=TNAV
# end:https://finance.yahoo.com/quote/TNC/financials?p=TNC
# end:https://finance.yahoo.com/quote/TNDM/financials?p=TNDM
# end:https://finance.yahoo.com/quote/TNET/financials?p=TNET
# end:https://finance.yahoo.com/quote/TNP/financials?p=TNP
# end:https://finance.yahoo.com/quote/TNXP/financials?p=TNXP
# end:https://finance.yahoo.com/quote/TOL/financials?p=TOL
# end:https://finance.yahoo.com/quote/TOWN/financials?p=TOWN
# end:https://finance.yahoo.com/quote/TPC/financials?p=TPC
# end:https://finance.yahoo.com/quote/TPCO/financials?p=TPCO
# end:https://finance.yahoo.com/quote/TPH/financials?p=TPH
# end:https://finance.yahoo.com/quote/TPIC/financials?p=TPIC
# end:https://finance.yahoo.com/quote/TPR/financials?p=TPR
# end:https://finance.yahoo.com/quote/TPRE/financials?p=TPRE
# end:https://finance.yahoo.com/quote/TPTX/financials?p=TPTX
# end:https://finance.yahoo.com/quote/TPX/financials?p=TPX
# end:https://finance.yahoo.com/quote/TR/financials?p=TR
# end:https://finance.yahoo.com/quote/TRC/financials?p=TRC
# end:https://finance.yahoo.com/quote/TREC/financials?p=TREC
# end:https://finance.yahoo.com/quote/TREE/financials?p=TREE
# end:https://finance.yahoo.com/quote/TREX/financials?p=TREX
# end:https://finance.yahoo.com/quote/TRGP/financials?p=TRGP
# end:https://finance.yahoo.com/quote/TRHC/financials?p=TRHC
# end:https://finance.yahoo.com/quote/TRI/financials?p=TRI
# end:https://finance.yahoo.com/quote/TRIP/financials?p=TRIP
# end:https://finance.yahoo.com/quote/VECO/financials?p=VECO
# end:https://finance.yahoo.com/quote/VEEV/financials?p=VEEV
# end:https://finance.yahoo.com/quote/VEL/financials?p=VEL
# end:https://finance.yahoo.com/quote/VERI/financials?p=VERI
# end:https://finance.yahoo.com/quote/VERU/financials?p=VERU
# end:https://finance.yahoo.com/quote/VERX/financials?p=VERX
# end:https://finance.yahoo.com/quote/VERY/financials?p=VERY
# end:https://finance.yahoo.com/quote/VFC/financials?p=VFC
# end:https://finance.yahoo.com/quote/VG/financials?p=VG
# end:https://finance.yahoo.com/quote/VGR/financials?p=VGR
# end:https://finance.yahoo.com/quote/VHC/financials?p=VHC
# end:https://finance.yahoo.com/quote/VHI/financials?p=VHI
# end:https://finance.yahoo.com/quote/VIAC/financials?p=VIAC
# end:https://finance.yahoo.com/quote/VIAV/financials?p=VIAV
# end:https://finance.yahoo.com/quote/VICR/financials?p=VICR
# end:https://finance.yahoo.com/quote/VIE/financials?p=VIE
# end:https://finance.yahoo.com/quote/VIR/financials?p=VIR
# end:https://finance.yahoo.com/quote/VIRT/financials?p=VIRT
# end:https://finance.yahoo.com/quote/VITL/financials?p=VITL
# end:https://finance.yahoo.com/quote/VIVE/financials?p=VIVE
# end:https://finance.yahoo.com/quote/VIVO/financials?p=VIVO
# end:https://finance.yahoo.com/quote/VKTX/financials?p=VKTX

# %%
# !pip install --upgrade -q gspread
#!pip install -U tensorflow-gpu==2.0.0 grpcio

import requests
from bs4 import BeautifulSoup
import re
import json
from google.colab import auth
import gspread
from oauth2client.client import GoogleCredentials
import types
import time
from google.colab import drive

#スプレッドシート認証処理
auth.authenticate_user()
gc = gspread.authorize(GoogleCredentials.get_application_default())

drive.mount('/content/drive')
with open('/content/drive/My Drive/foo.txt', 'w') as f:
  f.write('Hello Google Drive!')

#ティッカー一覧を取得
ss_url = "初心者のための投資講座"
workbook = gc.open(ss_url)
worksheet = workbook.worksheet("ticker_list")
#cell_list = worksheet.range("A3:A3865")
cell_list = []
for cell in worksheet.range("A3:A5"):
  cell_list.append(cell.value)

class Settlement:
  BASE_FINANCIALS_URL='https://finance.yahoo.com/quote/{0}/financials?p={0}'
  BASE_CASHFLOW_URL='https://finance.yahoo.com/quote/{0}/cash-flow?p={0}'
  outPutDict = {}
  errCnt = 0

  def checkKey(target,key,selt):
    if key in target.keys():
      return true
    else:
      return false

  def getJScript(self,url):
    r = requests.get(url)
    print(r.status_code)
    
    html = r.text
    soup = BeautifulSoup(html,'html.parser')
    soup_script = soup.find("script",text=re.compile("root.App.main")).text
    return json.loads(re.search("root.App.main\s+=\s+(\{.*\})",soup_script)[1])
  
  def getData(self,i):
    try:
      fUrl = self.BASE_FINANCIALS_URL.format(cell_list[i])
      fJScript = self.getJScript(fUrl)
      fQSS = fJScript['context']['dispatcher']['stores']['QuoteSummaryStore']

      print("start:" + fUrl)

      if fQSS['cashflowStatementHistory'] is None or len(fQSS['cashflowStatementHistory']) == 0:
        print("cashflowStatementHistory:None")
        return None
      else:
        fCFS = fQSS['cashflowStatementHistory']['cashflowStatements']
      fISH = fQSS['incomeStatementHistory']['incomeStatementHistory']

      #if fJScript['context']['dispatcher']['stores']['QuoteTimeSeriesStore']['timeSeries'] is None:
      #  print("timeSeries:None")
      #  return None
      #else:
      #  fADAS = fJScript['context']['dispatcher']['stores']['QuoteTimeSeriesStore']['timeSeries']['annualDilutedAverageShares']
      fADAS = fJScript['context']['dispatcher']['stores']['QuoteTimeSeriesStore']['timeSeries']['annualDilutedAverageShares']

      cUrl = self.BASE_CASHFLOW_URL.format(cell_list[i])
      cJScript = self.getJScript(cUrl)
      cQSS = cJScript['context']['dispatcher']['stores']['QuoteSummaryStore']

      cCFS = cQSS['cashflowStatementHistory']['cashflowStatements']
      
      #max3年のデータがほしいけど、0~2も存在する。
      roopCnt = len(fADAS) -1
      if roopCnt < 0:
        return None
      fadasiBaseCnt = roopCnt - 1

      #if cell_list[i] == 'ACET'
      #print("fCFS"+str(len(fCFS)))
      #print("fISH"+str(len(fISH)))
      #print("fADAS"+str(len(fADAS)))
      #print("cCFS"+str(len(cCFS)))
      
      #print("roopCnt:" + str(roopCnt))
      print("end:" + fUrl)

      for j in range(roopCnt):
         fadasi = fadasiBaseCnt-j
         dataDict = {}
         dataDict['endDate'] = fCFS[j]['endDate']['fmt'] if 'endDate' in fCFS[j].keys() else ''
         dataDict['netIncome'] = fCFS[j]['netIncome']['longFmt'] if 'netIncome' in fCFS[j].keys() else ''
         dataDict['totalRevenue'] = fISH[j]['totalRevenue']['longFmt'] if 'totalRevenue' in fISH[j].keys() else ''
         dataDict['reportedValue'] = fADAS[fadasi]['reportedValue']['raw'] if 'reportedValue' in fADAS[fadasi].keys() else ''
         dataDict['totalCashFromOperatingActivities'] = cCFS[j]['totalCashFromOperatingActivities']['longFmt'] if 'totalCashFromOperatingActivities' in fCFS[j].keys() else ''
         dataDict['dividendsPaid'] = cCFS[j]['dividendsPaid']['longFmt'] if 'dividendsPaid' in cCFS[j].keys() else ''

         # カンマ除去
         dataDict['netIncome'] = dataDict['netIncome'].replace(',', '')
         dataDict['totalRevenue'] = dataDict['totalRevenue'].replace(',', '')
         dataDict['totalCashFromOperatingActivities'] = dataDict['totalCashFromOperatingActivities'].replace(',', '')
         dataDict['dividendsPaid'] = dataDict['dividendsPaid'].replace('-', '') #配当は-は除去する
         dataDict['dividendsPaid'] = dataDict['dividendsPaid'].replace(',', '')

         key = cell_list[i] + '_' + dataDict['endDate']
         self.outPutDict[key] = dataDict
    except:
        if self.errCnt < 5:
          print(self.errCnt)
          print("こけた！")
          self.errCnt = self.errCnt + 1
          self.getData(i)

  def getAllData(self):
    for i in range(len(cell_list)):
      self.errCnt = 0
      self.getData(i)
      #time.sleep(5)

S = Settlement()
allData = {}
S.getAllData()
allData = S.outPutDict

ky = 1
worksheet_output_list = workbook.worksheet("output_list")
for symbl,d in allData.items():
  kx = 1
  for k,v in d.items():
    if kx == 1:
      worksheet_output_list.update_cell(ky, kx, symbl)
    else:
      worksheet_output_list.update_cell(ky, kx, v)
    kx += 1
  ky += 1
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# 200
# start:https://finance.yahoo.com/quote/A/financials?p=A
# 200
# end:https://finance.yahoo.com/quote/A/financials?p=A
# 200
# start:https://finance.yahoo.com/quote/AA/financials?p=AA
# 200
# end:https://finance.yahoo.com/quote/AA/financials?p=AA
# 200
# start:https://finance.yahoo.com/quote/AAL/financials?p=AAL
# 200
# end:https://finance.yahoo.com/quote/AAL/financials?p=AAL
